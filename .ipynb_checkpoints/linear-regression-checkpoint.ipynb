# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# House size (in 1000 sq ft)
x = np.array([0.5, 1.0, 1.5, 2.0, 2.5, 3.0])

# Price (in lakhs)
y = np.array([50, 80, 110, 130, 150, 180])

m = len(x)

plt.scatter(x, y)
plt.title("House Prices vs Size")
plt.xlabel("Size (1000 sq ft)")
plt.ylabel("Price (Lakhs)")
plt.show()

# %%
def predict(x, w, b):
    return w * x + b

# %%
def compute_cost(x, y, w, b):
    m = len(x)
    cost = 0

    for i in range(m):
        y_pred = w * x[i] + b
        error = y_pred - y[i]
        cost += error ** 2
    return cost / (2 * m)

# %%
def gradient_descent(x, y, w, b, alpha, iterations):
    m = len(x)

    cost_history = []
    w_history = []

    for iter in range(iterations):
        dj_dw = 0
        dj_db = 0

        #calculate Gradients
        for i in range(m):
            y_pred = w * x[i] + b
            error = y_pred - y[i]

            dj_dw += error * x[i]
            dj_db += error

        dj_dw /= m
        dj_db /= m


        #update params
        w = w - alpha * dj_dw
        b = b - alpha * dj_db

        #save history
        cost = compute_cost(x, y, w, b)
        cost_history.append(cost)
        w_history.append(w)

        #print progress every 1000 steps
        if iter % 100 == 0:
            print(f"iteration{iter}: Cost={cost: .2f},w={w:.2f}, b={b:.2f}")

    return  w, b, cost_history, w_history

# %%
w = 0
b = 0
alpha = 0.01
iterations = 1000

w, b, cost_history, w_history = gradient_descent(x, y, w, b, alpha, iterations)

print("\nFinal values:")
print("w =", w)
print("b =", b)
# Out:
# iteration0: Cost= 7033.81,w=2.41, b=1.17
# iteration100: Cost= 7.33,w=51.34, b=25.38
# iteration200: Cost= 6.55,w=51.55, b=26.03
# iteration300: Cost= 6.36,w=51.37, b=26.42
# iteration400: Cost= 6.23,w=51.21, b=26.74
# iteration500: Cost= 6.13,w=51.08, b=27.02
# iteration600: Cost= 6.06,w=50.96, b=27.26
# iteration700: Cost= 6.01,w=50.86, b=27.47
# iteration800: Cost= 5.97,w=50.78, b=27.64
# iteration900: Cost= 5.95,w=50.71, b=27.79
#
# Final values:
# w = 50.64617346363855
# b = 27.918080229534

# %%
y_pred = predict(x, w, b)


plt.scatter(x, y, label="Actual Data")
plt.plot(x, y_pred, color='red', label="Regression Line")
plt.xlabel("Size")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
x = np.array(x)
y = np.array(y)

# %%
plt.plot(cost_history)
plt.title("Cost vs Iterations")
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.show()

# %%
size = 2.2  # 2200 sq ft
predicted_price = predict(size, w, b)

print(f"Predicted price for {size*1000} sq ft: {predicted_price:.2f} lakhs")
# Out:
# Predicted price for 2200.0 sq ft: 139.34 lakhs
